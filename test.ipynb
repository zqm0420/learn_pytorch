# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

import torchvision
from torchvision.transforms import transforms

from itertools import product
from collections import OrderedDict,namedtuple

# %%
train_set = torchvision.datasets.FashionMNIST(root='./data',
                                              train=True,
                                              transform=transforms.Compose([transforms.ToTensor()]),
                                              download=True)

# %%
test_set = torchvision.datasets.FashionMNIST(root='./data',
                                             train=False, 
                                             transform=transforms.Compose([transforms.ToTensor()]),
                                             download=True)

# %%
params = OrderedDict(
    lr = [0.01],
    batch_size=[64],
    shuffle = [True],
    momentum = [0.9],
)

# %%
class RunBuilder():
    @staticmethod
    def get_runs(params):
        Run = namedtuple('Run',params.keys())
        
        runs = []
        for v in product(*params.values()):
            runs.append(Run(*v))
        return runs

# %%
class Network(torch.nn.Module):
    def __init__(self):
        super(Network,self).__init__()
        self.conv1 = torch.nn.Conv2d(in_channels=1, out_channels=32, kernel_size=5, padding=2)
        self.norm1 = nn.BatchNorm2d(32)
        nn.init.xavier_uniform_(self.conv1.weight)
        
        self.conv2 = torch.nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=2)
        self.norm2 = nn.BatchNorm2d(64)
        nn.init.xavier_uniform_(self.conv2.weight)
        
        self.fc1 = torch.nn.Linear(in_features=4096, out_features=4096)
#         self.fc2 = torch.nn.Linear(in_features=300, out_features=60)
        self.out = torch.nn.Linear(in_features=4096, out_features=10)
        
    def forward(self,t):
        # 1. input layer
        t = t

        t = self.conv1(t)
        t = F.relu(t)
        t = self.norm1(t)
        t = F.max_pool2d(t,kernel_size=2, stride=2)
        
        t = self.conv2(t)
        t = F.relu(t)
        t = self.norm2(t)
        t = F.max_pool2d(t,kernel_size=2, stride=2)
        
        # 4. linear layer1
        t = t.reshape(-1,4096)
        t = self.fc1(t)
        t = F.relu(t)
        t = F.dropout(t, p=0.2)
        
        # 5. linear layer 2
#         t = self.fc2(t)
#         t = F.relu(t)
        
        # 6. output layer
        t = self.out(t)
#         t = F.softmax()
        
        return t

# %%
for run in RunBuilder.get_runs(params):
    network = Network().to('cuda')
    train_loader = DataLoader(train_set, batch_size=run.batch_size, shuffle=run.shuffle, num_workers=1)
    test_loader = DataLoader(test_set,  batch_size=len(test_set), shuffle=run.shuffle, num_workers=1)
    optimizer = torch.optim.SGD(network.parameters(),lr=run.lr, momentum=run.momentum)
    tb = SummaryWriter(comment=f'-{run}')

    for epoch in range(30):

        total_train_loss = 0
        total_train_correct = 0
        
        for train_batch in train_loader:
            train_images = train_batch[0].to('cuda')       
            train_labels = train_batch[1].to('cuda')       
            train_preds = network(train_images)    
            train_loss = F.cross_entropy(train_preds, train_labels)
            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()

            total_train_loss += train_loss.item()
            total_train_correct += train_preds.argmax(dim=1).eq(train_labels).sum().item()
        
        total_train_loss /= len(train_loader)
        train_accuracy = total_train_correct / len(train_set)
        
        with torch.no_grad():
            test_batch = next(iter(test_loader))
            test_images = test_batch[0].to('cuda')
            test_labels = test_batch[1].to('cuda')
            test_preds = network(test_images)
            total_test_loss = F.cross_entropy(test_preds, test_labels).item()
            test_accuracy = test_preds.argmax(dim=1).eq(test_labels).sum().item() / len(test_set)
        
        tb.add_scalars('Loss',{'train_loss':total_train_loss,
                               'test_loss':total_test_loss}, epoch)
        tb.add_scalars('Accuracy',{'train_accuracy':train_accuracy,
                                   'test_accuracy':test_accuracy}, epoch)
        
        print('epochs:',epoch,'train_loss:',total_train_loss,'train_accuracy',train_accuracy,'test_loss:',total_test_loss,'test_accuracy',test_accuracy)
        
    tb.close()
# Out:
# epochs: 0 train_loss: 0.521083555750247 train_accuracy 0.8327166666666667 test_loss: 0.5015164613723755 test_accuracy 0.8408
# epochs: 1 train_loss: 0.49087376323844323 train_accuracy 0.8443833333333334 test_loss: 0.49691879749298096 test_accuracy 0.8409
# epochs: 2 train_loss: 0.4961709981279841 train_accuracy 0.8412333333333334 test_loss: 0.48884570598602295 test_accuracy 0.8408
# epochs: 3 train_loss: 0.49178209036652215 train_accuracy 0.8442833333333334 test_loss: 0.5114157199859619 test_accuracy 0.8377
# epochs: 4 train_loss: 0.4925164584793262 train_accuracy 0.84455 test_loss: 0.4970649480819702 test_accuracy 0.8382
# epochs: 5 train_loss: 0.493261903715032 train_accuracy 0.84285 test_loss: 0.5326918959617615 test_accuracy 0.8138
# epochs: 6 train_loss: 0.4951879217235773 train_accuracy 0.8419333333333333 test_loss: 0.5050074458122253 test_accuracy 0.8343
# epochs: 7 train_loss: 0.49511187865154577 train_accuracy 0.8416833333333333 test_loss: 0.49550899863243103 test_accuracy 0.842
# epochs: 8 train_loss: 0.4961473538613777 train_accuracy 0.8422333333333333 test_loss: 0.5090100765228271 test_accuracy 0.8381
# epochs: 9 train_loss: 0.4977356673303698 train_accuracy 0.8406666666666667 test_loss: 0.5022786855697632 test_accuracy 0.8376
# epochs: 10 train_loss: 0.49820556169125574 train_accuracy 0.8417333333333333 test_loss: 0.5085407495498657 test_accuracy 0.8362
# epochs: 11 train_loss: 0.49753500673689566 train_accuracy 0.8414666666666667 test_loss: 0.5399573445320129 test_accuracy 0.8191
# epochs: 12 train_loss: 0.49637498868617425 train_accuracy 0.8425833333333334 test_loss: 0.5203568339347839 test_accuracy 0.819
# epochs: 13 train_loss: 0.49842011505988104 train_accuracy 0.84185 test_loss: 0.5124906897544861 test_accuracy 0.8421
# epochs: 14 train_loss: 0.5012644925541969 train_accuracy 0.8394333333333334 test_loss: 0.5378129482269287 test_accuracy 0.8315
# epochs: 15 train_loss: 0.49694491532057333 train_accuracy 0.8422 test_loss: 0.5296493768692017 test_accuracy 0.8272
# epochs: 16 train_loss: 0.49747842308809 train_accuracy 0.84165 test_loss: 0.5131606459617615 test_accuracy 0.8373
# epochs: 17 train_loss: 0.4959803204864327 train_accuracy 0.84375 test_loss: 0.49920281767845154 test_accuracy 0.841
# epochs: 18 train_loss: 0.4986825076374672 train_accuracy 0.84175 test_loss: 0.513836681842804 test_accuracy 0.8339
# epochs: 19 train_loss: 0.49843035152217724 train_accuracy 0.8412833333333334 test_loss: 0.4866929054260254 test_accuracy 0.8471
# epochs: 20 train_loss: 0.49925004810031287 train_accuracy 0.8403333333333334 test_loss: 0.5186010599136353 test_accuracy 0.8309
# epochs: 21 train_loss: 0.5011775514909199 train_accuracy 0.8409166666666666 test_loss: 0.5099355578422546 test_accuracy 0.8373
# epochs: 22 train_loss: 0.4975686823444834 train_accuracy 0.8418333333333333 test_loss: 0.5275703072547913 test_accuracy 0.818
# epochs: 23 train_loss: 0.4993515154446112 train_accuracy 0.8398333333333333 test_loss: 0.5021714568138123 test_accuracy 0.8407
# epochs: 24 train_loss: 0.497549924769127 train_accuracy 0.8416166666666667 test_loss: 0.4966210424900055 test_accuracy 0.8429
# epochs: 25 train_loss: 0.49666874158357 train_accuracy 0.84185 test_loss: 0.5125216245651245 test_accuracy 0.837
# epochs: 26 train_loss: 0.5000367108057303 train_accuracy 0.8416166666666667 test_loss: 0.5508329272270203 test_accuracy 0.8134
# epochs: 27 train_loss: 0.503626359741825 train_accuracy 0.8388666666666666 test_loss: 0.5203045606613159 test_accuracy 0.8318
# epochs: 28 train_loss: 0.5012165655904233 train_accuracy 0.8412166666666666 test_loss: 0.5203884840011597 test_accuracy 0.8201
# epochs: 29 train_loss: 0.5023779938025261 train_accuracy 0.8404333333333334 test_loss: 0.5063742995262146 test_accuracy 0.8411
# epochs: 0 train_loss: 0.3863107510832454 train_accuracy 0.8588166666666667 test_loss: 0.3284769654273987 test_accuracy 0.881
# epochs: 1 train_loss: 0.2890167792262172 train_accuracy 0.8952166666666667 test_loss: 0.29872557520866394 test_accuracy 0.8926
# epochs: 2 train_loss: 0.28018235700375743 train_accuracy 0.89855 test_loss: 0.30189427733421326 test_accuracy 0.8875
# epochs: 3 train_loss: 0.27321561484702866 train_accuracy 0.9012166666666667 test_loss: 0.29803386330604553 test_accuracy 0.8925
# epochs: 4 train_loss: 0.26853263893647233 train_accuracy 0.9026166666666666 test_loss: 0.28570571541786194 test_accuracy 0.8957
# epochs: 5 train_loss: 0.2705117226965519 train_accuracy 0.90245 test_loss: 0.3157443106174469 test_accuracy 0.8883
# epochs: 6 train_loss: 0.2667765298616022 train_accuracy 0.9035333333333333 test_loss: 0.2746019661426544 test_accuracy 0.9015
# epochs: 7 train_loss: 0.2680121257917078 train_accuracy 0.90285 test_loss: 0.3095538914203644 test_accuracy 0.8818
# epochs: 8 train_loss: 0.2647605634161404 train_accuracy 0.90515 test_loss: 0.28356021642684937 test_accuracy 0.897
# epochs: 9 train_loss: 0.26613314448992836 train_accuracy 0.9033333333333333 test_loss: 0.28998181223869324 test_accuracy 0.8947
# epochs: 10 train_loss: 0.2656299301000165 train_accuracy 0.9041333333333333 test_loss: 0.32083410024642944 test_accuracy 0.8848
# epochs: 11 train_loss: 0.2645635711056973 train_accuracy 0.90485 test_loss: 0.3121167719364166 test_accuracy 0.8887
# epochs: 12 train_loss: 0.26601755745343564 train_accuracy 0.9041333333333333 test_loss: 0.28503140807151794 test_accuracy 0.8978
# epochs: 13 train_loss: 0.26486974309232314 train_accuracy 0.90405 test_loss: 0.30903810262680054 test_accuracy 0.8878
# epochs: 14 train_loss: 0.26780283350203593 train_accuracy 0.90425 test_loss: 0.3158383071422577 test_accuracy 0.8874
# epochs: 15 train_loss: 0.2649169896107747 train_accuracy 0.9046833333333333 test_loss: 0.2940252423286438 test_accuracy 0.8956
# epochs: 16 train_loss: 0.2677861877770693 train_accuracy 0.90385 test_loss: 0.3545301854610443 test_accuracy 0.8692
# epochs: 17 train_loss: 0.2666929589866448 train_accuracy 0.9032333333333333 test_loss: 0.2784709334373474 test_accuracy 0.9017
# epochs: 18 train_loss: 0.2650369016616456 train_accuracy 0.9047666666666667 test_loss: 0.3191834092140198 test_accuracy 0.8884
# epochs: 19 train_loss: 0.26621840089591325 train_accuracy 0.9053333333333333 test_loss: 0.30177411437034607 test_accuracy 0.8895
# epochs: 20 train_loss: 0.2674834712275437 train_accuracy 0.9041 test_loss: 0.3000274896621704 test_accuracy 0.8938
# epochs: 21 train_loss: 0.26597480509263366 train_accuracy 0.9034 test_loss: 0.28144675493240356 test_accuracy 0.898
# epochs: 22 train_loss: 0.265372513850996 train_accuracy 0.9042 test_loss: 0.2970970869064331 test_accuracy 0.8919
# epochs: 23 train_loss: 0.2678983914556661 train_accuracy 0.9033 test_loss: 0.2890275716781616 test_accuracy 0.8955
# epochs: 24 train_loss: 0.2641616547698659 train_accuracy 0.9048833333333334 test_loss: 0.3058812618255615 test_accuracy 0.8898
# epochs: 25 train_loss: 0.266267909225561 train_accuracy 0.9031333333333333 test_loss: 0.2897355258464813 test_accuracy 0.8928
# epochs: 26 train_loss: 0.26624492535204775 train_accuracy 0.9038833333333334 test_loss: 0.29861119389533997 test_accuracy 0.891
# epochs: 27 train_loss: 0.26687627014066617 train_accuracy 0.9026666666666666 test_loss: 0.2983832061290741 test_accuracy 0.8924
# epochs: 28 train_loss: 0.2656632119229735 train_accuracy 0.9041666666666667 test_loss: 0.3059436082839966 test_accuracy 0.8874
# epochs: 29 train_loss: 0.2671300097902828 train_accuracy 0.9033 test_loss: 0.3011031150817871 test_accuracy 0.8937
